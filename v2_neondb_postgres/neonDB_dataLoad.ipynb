# %% [markdown]
# ## **NOTE :**
# This notebook is used for connecting to the cloud database, performing operations via Python, and avoiding repetitive tasks.

# %% [markdown]
# #### Loading data into Neon DB

# %%
import os
import pandas as pd
from sqlalchemy import create_engine

# %%
# NeonDB connection string 
engine = create_engine('your_neondb_connection_string_here')

csv_folder = r"G:\DataScience_projects\Text2Sql_chatbot\archive\all"  

for csv_file in os.listdir(csv_folder):
    if csv_file.endswith('.csv'):
        table_name = os.path.splitext(csv_file)[0]  # table name same as filename without extension
        file_path = os.path.join(csv_folder, csv_file)
        print(f"Importing {csv_file} into table {table_name}")
        
        df = pd.read_csv(file_path, sep="|")
        
        # Write to NeonDB (replace if table exists)
        df.to_sql(table_name, engine, if_exists='replace', index=False)

print("All CSV files imported successfully!")
# Out:
# Importing Agra.csv into table Agra
# Importing Ahmedabad.csv into table Ahmedabad
# Importing Ajmer.csv into table Ajmer
# Importing Alappuzha.csv into table Alappuzha
# Importing Allahabad.csv into table Allahabad
# Importing all_places.csv into table all_places
# Importing Amravati.csv into table Amravati
# Importing Amritsar.csv into table Amritsar
# Importing Aurangabad.csv into table Aurangabad
# Importing Bengaluru.csv into table Bengaluru
# Importing Bhopal.csv into table Bhopal
# Importing Bhubaneswar.csv into table Bhubaneswar
# Importing Chandigarh.csv into table Chandigarh
# Importing Chennai.csv into table Chennai
# Importing Coimbatore.csv into table Coimbatore
# Importing Cuttack.csv into table Cuttack
# Importing Darjeeling.csv into table Darjeeling
# Importing Dehradun.csv into table Dehradun
# Importing Delhi NCR.csv into table Delhi NCR
# Importing Dharamshala.csv into table Dharamshala
# Importing Gangtok.csv into table Gangtok
# Importing Goa.csv into table Goa
# Importing Gorakhpur.csv into table Gorakhpur
# Importing Guntur.csv into table Guntur
# Importing Guwahati.csv into table Guwahati
# Importing Gwalior.csv into table Gwalior
# Importing Haridwar.csv into table Haridwar
# Importing Hyderabad.csv into table Hyderabad
# Importing Indore.csv into table Indore
# Importing Jabalpur.csv into table Jabalpur
# Importing Jaipur.csv into table Jaipur
# Importing Jalandhar.csv into table Jalandhar
# Importing Jammu.csv into table Jammu
# Importing Jamnagar.csv into table Jamnagar
# Importing Jamshedpur.csv into table Jamshedpur
# Importing Jhansi.csv into table Jhansi
# Importing Jodhpur.csv into table Jodhpur
# Importing Kanpur.csv into table Kanpur
# Importing Kochi.csv into table Kochi
# Importing Kolhapur.csv into table Kolhapur
# Importing Kolkata.csv into table Kolkata
# Importing Kota.csv into table Kota
# Importing Lucknow.csv into table Lucknow
# Importing Ludhiana.csv into table Ludhiana
# Importing Madurai.csv into table Madurai
# Importing Manali.csv into table Manali
# Importing Mangalore.csv into table Mangalore
# Importing Manipal.csv into table Manipal
# Importing Meerut.csv into table Meerut
# Importing Mumbai.csv into table Mumbai
# Importing Mussoorie.csv into table Mussoorie
# Importing Mysore.csv into table Mysore
# Importing Nagpur.csv into table Nagpur
# Importing Nainital.csv into table Nainital
# Importing Nashik.csv into table Nashik
# Importing Neemrana.csv into table Neemrana
# Importing Ooty.csv into table Ooty
# Importing Palakkad.csv into table Palakkad
# Importing Patiala.csv into table Patiala
# Importing Patna.csv into table Patna
# Importing Puducherry.csv into table Puducherry
# Importing Pune.csv into table Pune
# Importing Pushkar.csv into table Pushkar
# Importing Raipur.csv into table Raipur
# Importing Rajkot.csv into table Rajkot
# Importing Ranchi.csv into table Ranchi
# Importing Rishikesh.csv into table Rishikesh
# Importing Salem.csv into table Salem
# Importing Shimla.csv into table Shimla
# Importing Siliguri.csv into table Siliguri
# Importing Srinagar.csv into table Srinagar
# Importing Surat.csv into table Surat
# Importing Thrissur.csv into table Thrissur
# Importing Tirupati.csv into table Tirupati
# Importing Trichy.csv into table Trichy
# Importing Trivandrum.csv into table Trivandrum
# Importing Udaipur.csv into table Udaipur
# Importing Vadodara.csv into table Vadodara
# Importing Varanasi.csv into table Varanasi
# Importing Vellore.csv into table Vellore
# Importing Vijayawada.csv into table Vijayawada
# Importing Visakhapatnam.csv into table Visakhapatnam
# All CSV files imported successfully!

# %% [markdown]
# ### Renaming column names into lower case since PosgreSQL is case sensitive

# %%
import psycopg2
import urllib.parse

# %%
# NeonDB connection parameters
conn = psycopg2.connect(
    host="your_hostname",
    dbname="your_dbname",
    user="your_username",
    password=urllib.parse.quote_plus("your_password"),
    port=5432,
    sslmode='require'
)

cur = conn.cursor()

# Get all tables in public schema
cur.execute("""
SELECT table_name
FROM information_schema.tables
WHERE table_schema='public' AND table_type='BASE TABLE';
""")
tables = cur.fetchall()

for (table_name,) in tables:
    # Get columns for each table
    cur.execute(f"""
    SELECT column_name FROM information_schema.columns
    WHERE table_name = '{table_name}' AND table_schema='public';
    """)
    columns = cur.fetchall()
    
    for (col,) in columns:
        new_col = col.lower().replace(" ", "_")
        if new_col != col:
            rename_sql = f'ALTER TABLE "{table_name}" RENAME COLUMN "{col}" TO {new_col};'
            print(rename_sql)  # Print or execute
            
            # Uncomment next line to run the rename command
            cur.execute(rename_sql)

# Commit changes if executed
conn.commit()
cur.close()
conn.close()
# Out:
# ALTER TABLE "ahmedabad" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "ahmedabad" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "ahmedabad" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "ahmedabad" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "ahmedabad" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "ahmedabad" RENAME COLUMN "URL" TO url;
# ALTER TABLE "ahmedabad" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "ahmedabad" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "ahmedabad" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "ahmedabad" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "ahmedabad" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "ahmedabad" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "ajmer" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "ajmer" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "ajmer" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "ajmer" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "ajmer" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "ajmer" RENAME COLUMN "URL" TO url;
# ALTER TABLE "ajmer" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "ajmer" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "ajmer" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "ajmer" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "ajmer" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "ajmer" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "alappuzha" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "alappuzha" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "alappuzha" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "alappuzha" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "alappuzha" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "alappuzha" RENAME COLUMN "URL" TO url;
# ALTER TABLE "alappuzha" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "alappuzha" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "alappuzha" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "alappuzha" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "alappuzha" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "alappuzha" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "allahabad" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "allahabad" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "allahabad" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "allahabad" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "allahabad" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "allahabad" RENAME COLUMN "URL" TO url;
# ALTER TABLE "allahabad" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "allahabad" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "allahabad" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "allahabad" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "allahabad" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "allahabad" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "amravati" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "amravati" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "amravati" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "amravati" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "amravati" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "amravati" RENAME COLUMN "URL" TO url;
# ALTER TABLE "amravati" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "amravati" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "amravati" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "amravati" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "amravati" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "amravati" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "all_places" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "all_places" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "all_places" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "all_places" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "all_places" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "all_places" RENAME COLUMN "URL" TO url;
# ALTER TABLE "all_places" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "all_places" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "all_places" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "all_places" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "all_places" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "all_places" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "amritsar" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "amritsar" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "amritsar" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "amritsar" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "amritsar" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "amritsar" RENAME COLUMN "URL" TO url;
# ALTER TABLE "amritsar" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "amritsar" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "amritsar" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "amritsar" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "amritsar" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "amritsar" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "aurangabad" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "aurangabad" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "aurangabad" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "aurangabad" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "aurangabad" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "aurangabad" RENAME COLUMN "URL" TO url;
# ALTER TABLE "aurangabad" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "aurangabad" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "aurangabad" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "aurangabad" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "aurangabad" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "aurangabad" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "bengaluru" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "bengaluru" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "bengaluru" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "bengaluru" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "bengaluru" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "bengaluru" RENAME COLUMN "URL" TO url;
# ALTER TABLE "bengaluru" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "bengaluru" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "bengaluru" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "bengaluru" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "bengaluru" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "bengaluru" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "bhopal" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "bhopal" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "bhopal" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "bhopal" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "bhopal" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "bhopal" RENAME COLUMN "URL" TO url;
# ALTER TABLE "bhopal" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "bhopal" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "bhopal" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "bhopal" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "bhopal" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "bhopal" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "URL" TO url;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "bhubaneswar" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "chandigarh" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "chandigarh" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "chandigarh" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "chandigarh" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "chandigarh" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "chandigarh" RENAME COLUMN "URL" TO url;
# ALTER TABLE "chandigarh" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "chandigarh" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "chandigarh" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "chandigarh" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "chandigarh" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "chandigarh" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "agra" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "agra" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "agra" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "agra" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "agra" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "agra" RENAME COLUMN "URL" TO url;
# ALTER TABLE "agra" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "agra" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "agra" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "agra" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "agra" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "agra" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "cuttack" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "cuttack" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "cuttack" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "cuttack" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "cuttack" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "cuttack" RENAME COLUMN "URL" TO url;
# ALTER TABLE "cuttack" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "cuttack" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "cuttack" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "cuttack" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "cuttack" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "cuttack" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "darjeeling" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "darjeeling" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "darjeeling" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "darjeeling" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "darjeeling" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "darjeeling" RENAME COLUMN "URL" TO url;
# ALTER TABLE "darjeeling" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "darjeeling" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "darjeeling" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "darjeeling" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "darjeeling" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "darjeeling" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "dehradun" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "dehradun" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "dehradun" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "dehradun" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "dehradun" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "dehradun" RENAME COLUMN "URL" TO url;
# ALTER TABLE "dehradun" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "dehradun" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "dehradun" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "dehradun" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "dehradun" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "dehradun" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "URL" TO url;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "delhi_ncr" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "chennai" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "chennai" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "chennai" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "chennai" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "chennai" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "chennai" RENAME COLUMN "URL" TO url;
# ALTER TABLE "chennai" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "chennai" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "chennai" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "chennai" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "chennai" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "chennai" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "coimbatore" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "coimbatore" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "coimbatore" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "coimbatore" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "coimbatore" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "coimbatore" RENAME COLUMN "URL" TO url;
# ALTER TABLE "coimbatore" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "coimbatore" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "coimbatore" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "coimbatore" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "coimbatore" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "coimbatore" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "dharamshala" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "dharamshala" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "dharamshala" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "dharamshala" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "dharamshala" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "dharamshala" RENAME COLUMN "URL" TO url;
# ALTER TABLE "dharamshala" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "dharamshala" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "dharamshala" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "dharamshala" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "dharamshala" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "dharamshala" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "gorakhpur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "gorakhpur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "gorakhpur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "gorakhpur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "gorakhpur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "gorakhpur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "gorakhpur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "gorakhpur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "gorakhpur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "gorakhpur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "gorakhpur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "gorakhpur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "guntur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "guntur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "guntur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "guntur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "guntur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "guntur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "guntur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "guntur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "guntur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "guntur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "guntur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "guntur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "guwahati" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "guwahati" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "guwahati" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "guwahati" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "guwahati" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "guwahati" RENAME COLUMN "URL" TO url;
# ALTER TABLE "guwahati" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "guwahati" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "guwahati" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "guwahati" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "guwahati" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "guwahati" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "gwalior" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "gwalior" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "gwalior" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "gwalior" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "gwalior" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "gwalior" RENAME COLUMN "URL" TO url;
# ALTER TABLE "gwalior" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "gwalior" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "gwalior" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "gwalior" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "gwalior" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "gwalior" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "haridwar" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "haridwar" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "haridwar" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "haridwar" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "haridwar" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "haridwar" RENAME COLUMN "URL" TO url;
# ALTER TABLE "haridwar" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "haridwar" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "haridwar" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "haridwar" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "haridwar" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "haridwar" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "hyderabad" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "hyderabad" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "hyderabad" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "hyderabad" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "hyderabad" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "hyderabad" RENAME COLUMN "URL" TO url;
# ALTER TABLE "hyderabad" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "hyderabad" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "hyderabad" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "hyderabad" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "hyderabad" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "hyderabad" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "indore" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "indore" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "indore" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "indore" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "indore" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "indore" RENAME COLUMN "URL" TO url;
# ALTER TABLE "indore" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "indore" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "indore" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "indore" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "indore" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "indore" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "jabalpur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "jabalpur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "jabalpur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "jabalpur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "jabalpur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "jabalpur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "jabalpur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "jabalpur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "jabalpur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "jabalpur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "jabalpur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "jabalpur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "jaipur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "jaipur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "jaipur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "jaipur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "jaipur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "jaipur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "jaipur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "jaipur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "jaipur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "jaipur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "jaipur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "jaipur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "gangtok" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "gangtok" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "gangtok" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "gangtok" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "gangtok" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "gangtok" RENAME COLUMN "URL" TO url;
# ALTER TABLE "gangtok" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "gangtok" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "gangtok" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "gangtok" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "gangtok" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "gangtok" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "goa" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "goa" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "goa" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "goa" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "goa" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "goa" RENAME COLUMN "URL" TO url;
# ALTER TABLE "goa" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "goa" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "goa" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "goa" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "goa" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "goa" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "jammu" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "jammu" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "jammu" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "jammu" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "jammu" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "jammu" RENAME COLUMN "URL" TO url;
# ALTER TABLE "jammu" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "jammu" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "jammu" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "jammu" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "jammu" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "jammu" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "jamnagar" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "jamnagar" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "jamnagar" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "jamnagar" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "jamnagar" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "jamnagar" RENAME COLUMN "URL" TO url;
# ALTER TABLE "jamnagar" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "jamnagar" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "jamnagar" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "jamnagar" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "jamnagar" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "jamnagar" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "jamshedpur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "jamshedpur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "jamshedpur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "jamshedpur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "jamshedpur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "jamshedpur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "jamshedpur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "jamshedpur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "jamshedpur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "jamshedpur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "jamshedpur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "jamshedpur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "jhansi" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "jhansi" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "jhansi" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "jhansi" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "jhansi" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "jhansi" RENAME COLUMN "URL" TO url;
# ALTER TABLE "jhansi" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "jhansi" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "jhansi" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "jhansi" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "jhansi" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "jhansi" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "jodhpur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "jodhpur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "jodhpur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "jodhpur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "jodhpur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "jodhpur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "jodhpur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "jodhpur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "jodhpur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "jodhpur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "jodhpur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "jodhpur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "kanpur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "kanpur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "kanpur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "kanpur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "kanpur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "kanpur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "kanpur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "kanpur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "kanpur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "kanpur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "kanpur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "kanpur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "kochi" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "kochi" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "kochi" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "kochi" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "kochi" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "kochi" RENAME COLUMN "URL" TO url;
# ALTER TABLE "kochi" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "kochi" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "kochi" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "kochi" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "kochi" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "kochi" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "kolhapur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "kolhapur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "kolhapur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "kolhapur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "kolhapur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "kolhapur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "kolhapur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "kolhapur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "kolhapur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "kolhapur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "kolhapur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "kolhapur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "kolkata" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "kolkata" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "kolkata" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "kolkata" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "kolkata" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "kolkata" RENAME COLUMN "URL" TO url;
# ALTER TABLE "kolkata" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "kolkata" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "kolkata" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "kolkata" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "kolkata" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "kolkata" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "jalandhar" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "jalandhar" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "jalandhar" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "jalandhar" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "jalandhar" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "jalandhar" RENAME COLUMN "URL" TO url;
# ALTER TABLE "jalandhar" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "jalandhar" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "jalandhar" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "jalandhar" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "jalandhar" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "jalandhar" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "madurai" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "madurai" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "madurai" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "madurai" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "madurai" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "madurai" RENAME COLUMN "URL" TO url;
# ALTER TABLE "madurai" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "madurai" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "madurai" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "madurai" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "madurai" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "madurai" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "manali" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "manali" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "manali" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "manali" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "manali" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "manali" RENAME COLUMN "URL" TO url;
# ALTER TABLE "manali" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "manali" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "manali" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "manali" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "manali" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "manali" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "lucknow" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "lucknow" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "lucknow" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "lucknow" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "lucknow" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "lucknow" RENAME COLUMN "URL" TO url;
# ALTER TABLE "lucknow" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "lucknow" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "lucknow" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "lucknow" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "lucknow" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "lucknow" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "ludhiana" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "ludhiana" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "ludhiana" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "ludhiana" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "ludhiana" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "ludhiana" RENAME COLUMN "URL" TO url;
# ALTER TABLE "ludhiana" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "ludhiana" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "ludhiana" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "ludhiana" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "ludhiana" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "ludhiana" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "meerut" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "meerut" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "meerut" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "meerut" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "meerut" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "meerut" RENAME COLUMN "URL" TO url;
# ALTER TABLE "meerut" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "meerut" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "meerut" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "meerut" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "meerut" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "meerut" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "mumbai" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "mumbai" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "mumbai" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "mumbai" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "mumbai" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "mumbai" RENAME COLUMN "URL" TO url;
# ALTER TABLE "mumbai" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "mumbai" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "mumbai" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "mumbai" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "mumbai" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "mumbai" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "mussoorie" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "mussoorie" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "mussoorie" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "mussoorie" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "mussoorie" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "mussoorie" RENAME COLUMN "URL" TO url;
# ALTER TABLE "mussoorie" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "mussoorie" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "mussoorie" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "mussoorie" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "mussoorie" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "mussoorie" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "mysore" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "mysore" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "mysore" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "mysore" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "mysore" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "mysore" RENAME COLUMN "URL" TO url;
# ALTER TABLE "mysore" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "mysore" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "mysore" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "mysore" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "mysore" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "mysore" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "nagpur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "nagpur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "nagpur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "nagpur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "nagpur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "nagpur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "nagpur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "nagpur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "nagpur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "nagpur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "nagpur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "nagpur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "nainital" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "nainital" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "nainital" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "nainital" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "nainital" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "nainital" RENAME COLUMN "URL" TO url;
# ALTER TABLE "nainital" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "nainital" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "nainital" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "nainital" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "nainital" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "nainital" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "nashik" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "nashik" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "nashik" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "nashik" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "nashik" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "nashik" RENAME COLUMN "URL" TO url;
# ALTER TABLE "nashik" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "nashik" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "nashik" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "nashik" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "nashik" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "nashik" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "neemrana" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "neemrana" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "neemrana" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "neemrana" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "neemrana" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "neemrana" RENAME COLUMN "URL" TO url;
# ALTER TABLE "neemrana" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "neemrana" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "neemrana" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "neemrana" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "neemrana" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "neemrana" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "ooty" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "ooty" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "ooty" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "ooty" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "ooty" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "ooty" RENAME COLUMN "URL" TO url;
# ALTER TABLE "ooty" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "ooty" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "ooty" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "ooty" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "ooty" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "ooty" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "palakkad" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "palakkad" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "palakkad" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "palakkad" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "palakkad" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "palakkad" RENAME COLUMN "URL" TO url;
# ALTER TABLE "palakkad" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "palakkad" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "palakkad" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "palakkad" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "palakkad" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "palakkad" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "patna" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "patna" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "patna" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "patna" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "patna" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "patna" RENAME COLUMN "URL" TO url;
# ALTER TABLE "patna" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "patna" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "patna" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "patna" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "patna" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "patna" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "puducherry" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "puducherry" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "puducherry" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "puducherry" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "puducherry" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "puducherry" RENAME COLUMN "URL" TO url;
# ALTER TABLE "puducherry" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "puducherry" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "puducherry" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "puducherry" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "puducherry" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "puducherry" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "patiala" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "patiala" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "patiala" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "patiala" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "patiala" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "patiala" RENAME COLUMN "URL" TO url;
# ALTER TABLE "patiala" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "patiala" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "patiala" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "patiala" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "patiala" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "patiala" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "mangalore" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "mangalore" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "mangalore" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "mangalore" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "mangalore" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "mangalore" RENAME COLUMN "URL" TO url;
# ALTER TABLE "mangalore" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "mangalore" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "mangalore" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "mangalore" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "mangalore" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "mangalore" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "manipal" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "manipal" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "manipal" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "manipal" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "manipal" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "manipal" RENAME COLUMN "URL" TO url;
# ALTER TABLE "manipal" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "manipal" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "manipal" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "manipal" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "manipal" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "manipal" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "pushkar" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "pushkar" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "pushkar" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "pushkar" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "pushkar" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "pushkar" RENAME COLUMN "URL" TO url;
# ALTER TABLE "pushkar" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "pushkar" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "pushkar" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "pushkar" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "pushkar" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "pushkar" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "raipur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "raipur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "raipur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "raipur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "raipur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "raipur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "raipur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "raipur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "raipur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "raipur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "raipur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "raipur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "rajkot" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "rajkot" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "rajkot" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "rajkot" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "rajkot" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "rajkot" RENAME COLUMN "URL" TO url;
# ALTER TABLE "rajkot" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "rajkot" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "rajkot" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "rajkot" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "rajkot" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "rajkot" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "ranchi" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "ranchi" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "ranchi" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "ranchi" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "ranchi" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "ranchi" RENAME COLUMN "URL" TO url;
# ALTER TABLE "ranchi" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "ranchi" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "ranchi" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "ranchi" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "ranchi" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "ranchi" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "rishikesh" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "rishikesh" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "rishikesh" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "rishikesh" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "rishikesh" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "rishikesh" RENAME COLUMN "URL" TO url;
# ALTER TABLE "rishikesh" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "rishikesh" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "rishikesh" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "rishikesh" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "rishikesh" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "rishikesh" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "salem" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "salem" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "salem" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "salem" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "salem" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "salem" RENAME COLUMN "URL" TO url;
# ALTER TABLE "salem" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "salem" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "salem" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "salem" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "salem" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "salem" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "shimla" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "shimla" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "shimla" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "shimla" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "shimla" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "shimla" RENAME COLUMN "URL" TO url;
# ALTER TABLE "shimla" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "shimla" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "shimla" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "shimla" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "shimla" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "shimla" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "siliguri" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "siliguri" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "siliguri" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "siliguri" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "siliguri" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "siliguri" RENAME COLUMN "URL" TO url;
# ALTER TABLE "siliguri" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "siliguri" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "siliguri" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "siliguri" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "siliguri" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "siliguri" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "srinagar" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "srinagar" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "srinagar" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "srinagar" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "srinagar" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "srinagar" RENAME COLUMN "URL" TO url;
# ALTER TABLE "srinagar" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "srinagar" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "srinagar" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "srinagar" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "srinagar" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "srinagar" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "surat" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "surat" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "surat" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "surat" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "surat" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "surat" RENAME COLUMN "URL" TO url;
# ALTER TABLE "surat" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "surat" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "surat" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "surat" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "surat" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "surat" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "thrissur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "thrissur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "thrissur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "thrissur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "thrissur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "thrissur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "thrissur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "thrissur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "thrissur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "thrissur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "thrissur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "thrissur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "tirupati" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "tirupati" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "tirupati" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "tirupati" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "tirupati" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "tirupati" RENAME COLUMN "URL" TO url;
# ALTER TABLE "tirupati" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "tirupati" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "tirupati" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "tirupati" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "tirupati" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "tirupati" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "trichy" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "trichy" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "trichy" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "trichy" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "trichy" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "trichy" RENAME COLUMN "URL" TO url;
# ALTER TABLE "trichy" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "trichy" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "trichy" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "trichy" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "trichy" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "trichy" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "pune" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "pune" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "pune" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "pune" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "pune" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "pune" RENAME COLUMN "URL" TO url;
# ALTER TABLE "pune" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "pune" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "pune" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "pune" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "pune" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "pune" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "kota" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "kota" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "kota" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "kota" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "kota" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "kota" RENAME COLUMN "URL" TO url;
# ALTER TABLE "kota" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "kota" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "kota" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "kota" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "kota" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "kota" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "trivandrum" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "trivandrum" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "trivandrum" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "trivandrum" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "trivandrum" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "trivandrum" RENAME COLUMN "URL" TO url;
# ALTER TABLE "trivandrum" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "trivandrum" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "trivandrum" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "trivandrum" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "trivandrum" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "trivandrum" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "udaipur" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "udaipur" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "udaipur" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "udaipur" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "udaipur" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "udaipur" RENAME COLUMN "URL" TO url;
# ALTER TABLE "udaipur" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "udaipur" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "udaipur" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "udaipur" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "udaipur" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "udaipur" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "vadodara" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "vadodara" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "vadodara" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "vadodara" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "vadodara" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "vadodara" RENAME COLUMN "URL" TO url;
# ALTER TABLE "vadodara" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "vadodara" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "vadodara" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "vadodara" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "vadodara" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "vadodara" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "varanasi" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "varanasi" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "varanasi" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "varanasi" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "varanasi" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "varanasi" RENAME COLUMN "URL" TO url;
# ALTER TABLE "varanasi" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "varanasi" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "varanasi" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "varanasi" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "varanasi" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "varanasi" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "vellore" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "vellore" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "vellore" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "vellore" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "vellore" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "vellore" RENAME COLUMN "URL" TO url;
# ALTER TABLE "vellore" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "vellore" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "vellore" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "vellore" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "vellore" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "vellore" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "vijayawada" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "vijayawada" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "vijayawada" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "vijayawada" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "vijayawada" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "vijayawada" RENAME COLUMN "URL" TO url;
# ALTER TABLE "vijayawada" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "vijayawada" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "vijayawada" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "vijayawada" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "vijayawada" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "vijayawada" RENAME COLUMN "VOTES" TO votes;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "NAME" TO name;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "PRICE" TO price;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "CUSINE_CATEGORY" TO cusine_category;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "CITY" TO city;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "REGION" TO region;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "URL" TO url;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "PAGE NO" TO page_no;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "CUSINE TYPE" TO cusine_type;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "TIMING" TO timing;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "RATING_TYPE" TO rating_type;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "RATING" TO rating;
# ALTER TABLE "visakhapatnam" RENAME COLUMN "VOTES" TO votes;
